# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDavid0460/POO_S2/blob/main/Unidad2/SistemaLibreria_version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Programacion orientada a Objetos
#
# ### Unidad 2
#
# ## **PROGRAMA DE LIBRERIA**
#
# ### Luis David Hernandez Gomez
# #### Ingenieria en sistemas Computacionales

# %%
from ast import Num
class Libro:
  def __init__(self, isbn, titulo, autor, categoria, precio):
    self.isbn = isbn
    self.titulo = titulo
    self.autor = autor
    self.categoria = categoria
    self.precio = precio
    self.prestado = False

  def mostrar_info(self):
    estado = "Prestado" if self.prestado else "Disponible"
    print(f"[{self.isbn}] {self.titulo} - {self.autor} | {self.categoria} | ${self.precio} |{estado}")

class estudiante:
  def __init__(self, num_control, nombre, carrera, fecha_nacimiento, telefono, correo):
    self.num_control = num_control
    self.nombre = nombre
    self.carrera = carrera
    self.fecha_nacimiento = fecha_nacimiento
    self.telefono = telefono
    self.correo = correo

  def mostrar_info(self):
    print(f"[{self.num_control}] {self.nombre} - {self.carrera} | Nac: {self.fecha_nacimiento} | / Tel: {self.telefono} | Correo: {self.correo}")


class Prestamo:
  contador_prestamos = 1

  def __init__(self, num_control, isbn, fecha_inicio, fecha_termino):
    self.folio = Prestamo.contador_prestamos
    Prestamo.contador_prestamos += 1
    self.num_control = num_control
    self.isbn = isbn
    self.fecha_inicio = fecha_inicio
    self.fecha_termino = fecha_termino

  def mostrar_info(self):
    print(f"Folio: {self.folio} | Estudiante: {self.num_control} | Libro: {self.isbn} \
    Del {self.fecha_inicio} al {self.fecha_termino}")

class Venta:
    contador_ventas = 1

    def __init__(self, isbn, num_control, fecha, cantidad, importe):
      self.folio_venta = Venta.contador_ventas
      Venta.contador_ventas += 1
      self.isbn = isbn
      self.num_control = num_control
      self.fecha = fecha
      self.cantidad = cantidad
      self.importe = importe

    def mostrar_info(self):
      print(f"Folio: {self.folio_venta} | ISBN: {self.isbn} | Comprador: {self.num_control} | \
      Fecha: {self.fecha} | Cantidad: {self.cantidad} | Importe: ${self.importe}")

###### FUNCIONES ######

def alta_libro():
  print("\n--- Alta de Libro ---")
  isbn = input("ISBN: ")
  for libro in libros:
    if libro.isbn == isbn:
      print("¡Ya existe un libro con ese ISBN!")
      return
  titulo = input("Titulo: ")
  autor = input("Autor: ")
  categoria = input("Categoria: ")
  try:
    precio = float(input("Precio: "))
  except ValueError:
    print("Precio inválido.")
    return
  nuevo_libro = Libro(isbn, titulo, autor, categoria, precio)
  libros.append(nuevo_libro)
  print("Libro registrado exitosamente.")

def alta_estudiante():
  print("\n--- Alta de Estudiante ---")
  num_control = input("Numero de control: ")
  for est in estudiantes:
    if est.num_control == num_control:
      print("¡Ya existe un estudiante con ese numero de control!")
      return
  nombre = input("Nombre: ")
  carrera = input("Carrera: ")
  fecha_nacimiento = input("Fecha de nacimiento (dd/mm/aaaa): ")
  telefono = input("Telefono: ")
  correo = input("Correo: ")
  nuevo_estudiante = estudiante(num_control, nombre, carrera, fecha_nacimiento, telefono, correo)
  estudiantes.append(nuevo_estudiante)
  print("Estudiante registrado exitosamente.")

def consultar_libro():
  print("\n--- Consultar Libro por ISBN ---")
  isbn = input("Ingrese el ISBN del libro: ")
  for libro in libros:
    if libro.isbn == isbn:
      libro.mostrar_info()
      return
  print("Libro no encontrado.")

def consultar_estudiante():
  print("\n--- Consultar Estudiante por Numero de control --")
  num_control = input("Ingrese el numero de control: ")
  for est in estudiantes:
    if est.num_control == num_control:
      est.mostrar_info()
      return
  print("Estudiante no encontrado.")

def mostrar_todos_libros():
    print("\n--- Lista de Libros ---")
    if not libros:
      print("No hay libros registrados.")
    else:
      for libro in libros:
        libro.mostrar_info()

def mostrar_todos_estudiantes():
      print("\n--- Lista de Estudiantes ---")
      if not estudiantes:
        print("No hay estudiantes registrados.")
      else:
        for current_est in estudiantes:
          current_est.mostrar_info()

def realizar_prestamo():
      print("\n--- Realizar Prestamo ---")
      num_control = input("Numero de control del estudiante: ")
      isbn = input("ISBN del libro: ")
      estudiante = next((e for e in estudiantes if e.num_control == num_control), None)
      if not estudiante:
        print("Estudiante no encontrado.")
        return
      libro = next((l for l in libros if l.isbn == isbn), None)
      if not libro:
        print("Libro no encontrado.")
        return
      if libro.prestado:
        print("El libro ya esta prestado.")
        return
      fecha_inicio = input("Fecha de inicio (dd/mm/aaaa): ")
      fecha_termino = input("Fecha de termino (dd/mm/aaaa): ")
      nuevo_prestamo = Prestamo(num_control, isbn, fecha_inicio, fecha_termino)
      prestamos.append(nuevo_prestamo)
      libro.prestado = True
      print(f"Prestamo registrado con folio {nuevo_prestamo.folio}.")

def mostrar_prestamos():
  print("\n--- Lista de Prestamos ---")
  if not prestamos:
    print("No hay prestamos registrados.")
  else:
    for p in prestamos:
      p.mostrar_info()

def devolver_libro():
  print("\n--- Devolver libro ---")
  try:
    folio = int(input("Folio del prestamo a devolver: "))
  except ValueError:
    print("Folio inválido.")
    return
  prestamo = next((p for p in prestamos if p.folio == folio), None)
  if not prestamo:
    print("Prestamo no encontrado.")
    return
  libro = next((l for l in libros if l.isbn == prestamo.isbn), None)
  if libro:
    libro.prestado = False
    prestamos.remove(prestamo)
    print(f"Libro '{libro.titulo}' devuelto correctamente.")
  else:
    print("Libro no encontrado")

def registrar_venta():
  print("\n--- Registrar Venta ---")
  isbn = input("ISBN del libro a vender: ")
  libro = next((l for l in libros if l.isbn == isbn), None)
  if not libro:
    print("Libro no encontrado.")
    return
  try:
    cantidad = int(input("Cantidad a vender (solo 1 por ahora): "))
    if cantidad != 1:
      print("Solo se permite vender 1 unidad.")
      return
  except ValueError:
    print("Cantidad invalida.")
    return
  num_control = input("Numero del control del comprador (999999 si es publico general): ")
  if num_control != "999999":
    estudiante = next((e for e in estudiantes if e.num == num_control), None)
    if not estudiante:
      print("Estudiante no encontrado.")
      return
  fecha = input("Fecha de la venta (dd/mm/aaaa): ")
  importe = libro.precio * cantidad
  venta = Venta(isbn, num_control, fecha, cantidad, importe)
  ventas.append(venta)
  ventas.append(libro)
  print(f"Venta registrada. Folio: {venta.folio_venta}")

def mostrar_historial_ventas():
  print("\n--- Historial de ventas ---")
  if not ventas:
    print("No hay ventas registradas.")
  else:
    for v in ventas:
      v.mostrar_info()


def mostrar_menu():
  print("\n--- SISTEMA DE LIBRERIA ESCOLAR ---")
  print("1. Dar de alta libro")
  print("2. Dar de alta estudiante")
  print("3. Consultar libro por ISBN")
  print("4. Consultar estudiante por numero de control")
  print("5. Mostrar todos los libros")
  print("6. Mostrar todos los estudiantes")
  print("7. Realizar prestamo")
  print("8. Mostrar prestamos")
  print("9. Devolver libro")
  print("10. Registrar ventas")
  print("11. Mostrar historial de venta")
  print("12. Salir del sistema")

def iniciar_sistema():
  while True:
      mostrar_menu()
      opcion = input("Seleccione una opcion: ")
      if opcion == "1":
        alta_libro()
      elif opcion == "2":
        alta_estudiante()
      elif opcion == "3":
        consultar_libro()
      elif opcion == "4":
        consultar_estudiante()
      elif opcion == "5":
        mostrar_todos_libros()
      elif opcion == "6":
        mostrar_todos_estudiantes()
      elif opcion == "7":
        realizar_prestamo()
      elif opcion == "8":
        mostrar_prestamos()
      elif opcion == "9":
        devolver_libro()
      elif opcion == "10":
        registrar_venta()
      elif opcion == "11":
        mostrar_historial_ventas()
      elif opcion == "12":
        print("Saliendo del sistema. ¡Hasta Luego!")
        break
      else:
        print("Opcion no valida. Intente de nuevo")


################### PROGRAMA PRINCIPAL #####################

# Iniciar el sistema
libros = []
estudiantes = []
prestamos = []
ventas = []

iniciar_sistema()
# Out:
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 5
#
# --- Lista de Libros ---
# No hay libros registrados.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 3
#
# --- Consultar Libro por ISBN ---
# Ingrese el ISBN del libro: 150
# Libro no encontrado.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 1
#
# --- Alta de Libro ---
# ISBN: 100
# Titulo: Principito
# Autor: hola
# Categoria: Aventura
# Precio: 1500
# Libro registrado exitosamente.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 1
#
# --- Alta de Libro ---
# ISBN: 120
# Titulo: Biblia
# Autor: Religiosa
# Categoria: Religioso
# Precio: 2500
# Libro registrado exitosamente.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 5
#
# --- Lista de Libros ---
# [100] Principito - hola | Aventura | $1500.0 |Disponible
# [120] Biblia - Religiosa | Religioso | $2500.0 |Disponible
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 2
#
# --- Alta de Estudiante ---
# Numero de control: 15250022
# Nombre: David
# Carrera: Ing. Civil
# Fecha de nacimiento (dd/mm/aaaa): 12/01/1745
# Telefono: 618239132
# Correo: patito@juan
# Estudiante registrado exitosamente.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 2
#
# --- Alta de Estudiante ---
# Numero de control: 1231231
# Nombre: hola
# Carrera: Arquitectura
# Fecha de nacimiento (dd/mm/aaaa): 12/07/2025
# Telefono: Patito@juan
# Correo: ElJuano
# Estudiante registrado exitosamente.
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 6
#
# --- Lista de Estudiantes ---
# [15250022] David - Ing. Civil | Nac: 12/01/1745 | / Tel: 618239132 | Correo: patito@juan
# [1231231] hola - Arquitectura | Nac: 12/07/2025 | / Tel: Patito@juan | Correo: ElJuano
#
# --- SISTEMA DE LIBRERIA ESCOLAR ---
# 1. Dar de alta libro
# 2. Dar de alta estudiante
# 3. Consultar libro por ISBN
# 4. Consultar estudiante por numero de control
# 5. Mostrar todos los libros
# 6. Mostrar todos los estudiantes
# 7. Realizar prestamo
# 8. Mostrar prestamos
# 9. Devolver libro
# 10. Registrar ventas
# 11. Mostrar historial de venta
# 12. Salir del sistema
# Seleccione una opcion: 10
#
# --- Registrar Venta ---
# ISBN del libro a vender: 120
# Cantidad a vender (solo 1 por ahora): 1
# Numero del control del comprador (999999 si es publico general): 15250022
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3236388858.py in <cell line: 0>()
#     270 ventas = []
#     271
# --> 272 iniciar_sistema()
#
# /tmp/ipython-input-3236388858.py in iniciar_sistema()
#     252         devolver_libro()
#     253       elif opcion == "10":
# --> 254         registrar_venta()
#     255       elif opcion == "11":
#     256         mostrar_historial_ventas()
#
# /tmp/ipython-input-3236388858.py in registrar_venta()
#     194   num_control = input("Numero del control del comprador (999999 si es publico general): ")
#     195   if num_control != "999999":
# --> 196     estudiante = next((e for e in estudiantes if e.num == num_control), None)
#     197     if not estudiante:
#     198       print("Estudiante no encontrado.")
#
# /tmp/ipython-input-3236388858.py in <genexpr>(.0)
#     194   num_control = input("Numero del control del comprador (999999 si es publico general): ")
#     195   if num_control != "999999":
# --> 196     estudiante = next((e for e in estudiantes if e.num == num_control), None)
#     197     if not estudiante:
#     198       print("Estudiante no encontrado.")
#
# AttributeError: 'estudiante' object has no attribute 'num'
