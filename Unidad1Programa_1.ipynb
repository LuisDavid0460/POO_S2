# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisDavid0460/POO_S2/blob/main/Unidad1Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programacion orientada a Objetos
#
# ## Unidad 1
#
# ### Programa 1. **Introduccion a Python**
#
# Nombre del alumno: Luis David Hernandez Gomez
#
# Facilitador: Jose Gabriel Rodriguez Rivas

# %%
# Variables en Python

x = 5
print(x)
# Out:
# 5

# %%
print("la variable x: ", x)
# Out:
# la variable x:  hola

# %%
x = "hola"

print(x *5)
# Out:
# holaholaholaholahola

# %%
a = 1001
b = 1000
if a > b:
  print("a es mayor que b")
  print(a, "es mayor que", b)
else:
  print("b es mayor que a")
  print(b, "es mayor que", a)
# Out:
# a es mayor que b
# 1001 es mayor que 1000

# %%
a = 1
while a < 10:
  print(a)
  print("Dentro del While")
  a = a + 1

print("Fuera del While")
# Out:
# 1
# Dentro del While
# 2
# Dentro del While
# 3
# Dentro del While
# 4
# Dentro del While
# 5
# Dentro del While
# 6
# Dentro del While
# 7
# Dentro del While
# 8
# Dentro del While
# 9
# Dentro del While
# Fuera del While

# %%
for i in range(1, 10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
